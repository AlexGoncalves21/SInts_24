# %% [markdown]
# #### Importing and preprocessing the data

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from pyfume.Clustering import Clusterer
from pyfume.EstimateAntecendentSet import AntecedentEstimator
from pyfume.EstimateConsequentParameters import ConsequentEstimator
from pyfume.SimpfulModelBuilder import SugenoFISBuilder
from pyfume.Tester import SugenoFISTester
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, cohen_kappa_score
from numpy import clip, column_stack, argmax

data = pd.read_csv('wbco.csv',header=None)
indexes = ['LThick', 'UCellSize', 'UCellShape', 'MAdhesion', 'SECS', 'BlandC', 'NormNuc', 'Mitoses', 'Unknown', 'Target']
data.columns = indexes

indexes = indexes[:-1]

# %%
data.head()
# Out:
#    LThick  UCellSize  UCellShape  MAdhesion  SECS BlandC  NormNuc  Mitoses  \
# 0       5          1           1          1     2      1        3        1
# 1       5          4           4          5     7     10        3        2
# 2       3          1           1          1     2      2        3        1
# 3       6          8           8          1     3      4        3        7
# 4       4          1           1          3     2      1        3        1
#
#    Unknown  Target
# 0        1       0
# 1        1       0
# 2        1       0
# 3        1       0
# 4        1       0

# %%
data.describe()
# Out:
#            LThick   UCellSize  UCellShape   MAdhesion        SECS     NormNuc  \
# count  699.000000  699.000000  699.000000  699.000000  699.000000  699.000000
# mean     4.417740    3.134478    3.207439    2.806867    3.216023    3.437768
# std      2.815741    3.051459    2.971913    2.855379    2.214300    2.438364
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      2.000000    1.000000    1.000000    1.000000    2.000000    2.000000
# 50%      4.000000    1.000000    1.000000    1.000000    2.000000    3.000000
# 75%      6.000000    5.000000    5.000000    4.000000    4.000000    5.000000
# max     10.000000   10.000000   10.000000   10.000000   10.000000   10.000000
#
#           Mitoses     Unknown      Target
# count  699.000000  699.000000  699.000000
# mean     2.866953    1.589413    0.344778
# std      3.053634    1.715078    0.475636
# min      1.000000    1.000000    0.000000
# 25%      1.000000    1.000000    0.000000
# 50%      1.000000    1.000000    0.000000
# 75%      4.000000    1.000000    1.000000
# max     10.000000   10.000000    1.000000

# %%
data.isnull().sum()
# Out:
# LThick        0
# UCellSize     0
# UCellShape    0
# MAdhesion     0
# SECS          0
# BlandC        0
# NormNuc       0
# Mitoses       0
# Unknown       0
# Target        0
# dtype: int64

# %%
data.dtypes == int
# Out:
# LThick        False
# UCellSize     False
# UCellShape    False
# MAdhesion     False
# SECS          False
# BlandC         True
# NormNuc       False
# Mitoses       False
# Unknown       False
# Target        False
# dtype: bool

# %% [markdown]
# A variável 'BlandC' está atualmente definida como string pois possui algumas entradas com '?'. Como resolver este problema? O número de entradas sem valor é significativo?

# %%
na_perc = (data.BlandC[data.BlandC == '?']).count() / data.BlandC.count() * 100
print(str(na_perc) + '% percent of entries are null.')
# Out:
# 2.28898426323319% percent of entries are null.

# %% [markdown]
# Selected aproach: fill missing values with the column's average.

# %%
avg = data.BlandC[data.BlandC != '?'].astype(float).mean()
data.loc[data.BlandC == '?', 'BlandC'] = avg
data.BlandC = data.BlandC.astype(int)

# %% [markdown]
# Creating a train-test split

# %%
data_x = data.drop('Target', axis = 1)
data_y = data.Target

x_train, x_test, y_train, y_test = train_test_split(data_x, data_y, test_size = 0.2, random_state=21)

# %% [markdown]
# Formating the data to numpy

# %%
x_train = x_train.to_numpy()
x_test = x_test.to_numpy()
y_train = y_train.array
y_test = y_test.array

# %% [markdown]
# #### Building the model

# %%
cl = Clusterer(x_train=x_train, y_train=y_train, nr_clus=4)
clust_centers, part_matrix, _ = cl.cluster(method='fcm')

ae = AntecedentEstimator(x_train, part_matrix)
antecedent_params = ae.determineMF()

ce = ConsequentEstimator(x_train, y_train, part_matrix)
conseq_params = ce.suglms()

modbuilder = SugenoFISBuilder(antecedent_params, conseq_params, indexes, save_simpful_code=False)
model = modbuilder.get_model()

modtester = SugenoFISTester(model, x_test, indexes)
y_pred_probs = clip(modtester.predict()[0], 0, 1)
y_pred_probs = column_stack((1 - y_pred_probs, y_pred_probs))
y_pred = argmax(y_pred_probs,axis=1)

acc_score = accuracy_score(y_test, y_pred)
print("Accuracy: {:.3f}".format(acc_score))
rec_score = recall_score(y_test, y_pred)
print("Recall: {:.3f}".format(rec_score))
prec_score = precision_score(y_test, y_pred)
print("Precision Score: {:.3f}".format(prec_score))
F1_score = f1_score(y_test, y_pred)
print("F1-Score: {:.3f}".format(F1_score))
kappa = cohen_kappa_score(y_test, y_pred)
print("Kappa Score: {:.3f}".format(kappa))
# Out:
#  * Detected 4 rules / clusters
#  * Detected Sugeno model type
# Accuracy: 0.971
# Recall: 0.976
# Precision Score: 0.930
# F1-Score: 0.952
# Kappa Score: 0.932

# %%
for  nr_clus in range(2, 30):
    print(f"Clustering with {nr_clus} clusters")

    # Clustering
    cl = Clusterer(x_train=x_train, y_train=y_train, nr_clus=nr_clus)
    clust_centers, part_matrix, _ = cl.cluster(method='fcm')

    # Antecedent Estimation
    ae = AntecedentEstimator(x_train, part_matrix)
    antecedent_params = ae.determineMF()

    # Consequent Estimation
    ce = ConsequentEstimator(x_train, y_train, part_matrix)
    conseq_params = ce.suglms()

    # Model Building
    modbuilder = SugenoFISBuilder(antecedent_params, conseq_params, indexes, save_simpful_code=False)
    model = modbuilder.get_model()

    # Model Testing
    modtester = SugenoFISTester(model, x_test, indexes)
    y_pred_probs = clip(modtester.predict()[0], 0, 1)
    y_pred_probs = column_stack((1 - y_pred_probs, y_pred_probs))
    y_pred = argmax(y_pred_probs, axis=1)

    # Evaluation Metrics
    acc_score = accuracy_score(y_test, y_pred)
    rec_score = recall_score(y_test, y_pred)
    prec_score = precision_score(y_test, y_pred)
    F1_score = f1_score(y_test, y_pred)
    kappa = cohen_kappa_score(y_test, y_pred)

    # Print metrics
    print("Accuracy: {:.3f}".format(acc_score))
    print("Recall: {:.3f}".format(rec_score))
    print("Precision Score: {:.3f}".format(prec_score))
    print("F1-Score: {:.3f}".format(F1_score))
    print("Kappa Score: {:.3f}".format(kappa))
    print("=" * 30)
# Out:
# Clustering with 2 clusters
#  * Detected 2 rules / clusters
#  * Detected Sugeno model type
# Accuracy: 0.957
# Recall: 0.925
# Precision Score: 0.961
# F1-Score: 0.942
# Kappa Score: 0.908
# ==============================
# Clustering with 3 clusters
#  * Detected 3 rules / clusters
#  * Detected Sugeno model type
# Accuracy: 0.957
# Recall: 0.925
# Precision Score: 0.961
# F1-Score: 0.942
# Kappa Score: 0.908
# ==============================
# Clustering with 4 clusters
#  * Detected 4 rules / clusters
#  * Detected Sugeno model type
# Accuracy: 0.957
# Recall: 0.925
# Precision Score: 0.961
# F1-Score: 0.942
# Kappa Score: 0.908
# ==============================
# Clustering with 5 clusters
#  * Detected 5 rules / clusters
#  * Detected Sugeno model type
# Accuracy: 0.957
# Recall: 0.925
# Precision Score: 0.961
# F1-Score: 0.942
# Kappa Score: 0.908
# ==============================
# Clustering with 6 clusters
#  * Detected 6 rules / clusters
#  * Detected Sugeno model type
# Accuracy: 0.957
# Recall: 0.925
# Precision Score: 0.961
# F1-Score: 0.942
# Kappa Score: 0.908
# ==============================
# Clustering with 7 clusters
#  * Detected 7 rules / clusters
#  * Detected Sugeno model type
# Accuracy: 0.957
# Recall: 0.925
# Precision Score: 0.961
# F1-Score: 0.942
# Kappa Score: 0.908
# ==============================
# Clustering with 8 clusters
#  * Detected 8 rules / clusters
#  * Detected Sugeno model type
# Accuracy: 0.957
# Recall: 0.925
# Precision Score: 0.961
# F1-Score: 0.942
# Kappa Score: 0.908
# ==============================
# Clustering with 9 clusters
#  * Detected 9 rules / clusters
#  * Detected Sugeno model type
# Accuracy: 0.957
# Recall: 0.925
# Precision Score: 0.961
# F1-Score: 0.942
# Kappa Score: 0.908
# ==============================
# Clustering with 10 clusters
#  * Detected 10 rules / clusters
#  * Detected Sugeno model type
# Accuracy: 0.957
# Recall: 0.925
# Precision Score: 0.961
# F1-Score: 0.942
# Kappa Score: 0.908
# ==============================
# Clustering with 11 clusters
#  * Detected 11 rules / clusters
#  * Detected Sugeno model type
# Accuracy: 0.957
# Recall: 0.925
# Precision Score: 0.961
# F1-Score: 0.942
# Kappa Score: 0.908
# ==============================
# Clustering with 12 clusters
#  * Detected 12 rules / clusters
#  * Detected Sugeno model type
# Accuracy: 0.957
# Recall: 0.925
# Precision Score: 0.961
# F1-Score: 0.942
# Kappa Score: 0.908
# ==============================
# Clustering with 13 clusters
#  * Detected 13 rules / clusters
#  * Detected Sugeno model type
# Accuracy: 0.957
# Recall: 0.925
# Precision Score: 0.961
# F1-Score: 0.942
# Kappa Score: 0.908
# ==============================
# Clustering with 14 clusters
#  * Detected 14 rules / clusters
#  * Detected Sugeno model type
# Accuracy: 0.957
# Recall: 0.925
# Precision Score: 0.961
# F1-Score: 0.942
# Kappa Score: 0.908
# ==============================
# Clustering with 15 clusters
#  * Detected 15 rules / clusters
#  * Detected Sugeno model type
# Accuracy: 0.957
# Recall: 0.925
# Precision Score: 0.961
# F1-Score: 0.942
# Kappa Score: 0.908
# ==============================
# Clustering with 16 clusters
#  * Detected 16 rules / clusters
#  * Detected Sugeno model type
# Accuracy: 0.957
# Recall: 0.925
# Precision Score: 0.961
# F1-Score: 0.942
# Kappa Score: 0.908
# ==============================
# Clustering with 17 clusters
#  * Detected 17 rules / clusters
#  * Detected Sugeno model type
# Accuracy: 0.957
# Recall: 0.925
# Precision Score: 0.961
# F1-Score: 0.942
# Kappa Score: 0.908
# ==============================
# Clustering with 18 clusters
#  * Detected 18 rules / clusters
#  * Detected Sugeno model type
# Accuracy: 0.957
# Recall: 0.925
# Precision Score: 0.961
# F1-Score: 0.942
# Kappa Score: 0.908
# ==============================
# Clustering with 19 clusters
#  * Detected 19 rules / clusters
#  * Detected Sugeno model type
# Accuracy: 0.957
# Recall: 0.925
# Precision Score: 0.961
# F1-Score: 0.942
# Kappa Score: 0.908
# ==============================
# Clustering with 20 clusters
#  * Detected 20 rules / clusters
#  * Detected Sugeno model type
# Accuracy: 0.957
# Recall: 0.925
# Precision Score: 0.961
# F1-Score: 0.942
# Kappa Score: 0.908
# ==============================
# Clustering with 21 clusters
#  * Detected 21 rules / clusters
#  * Detected Sugeno model type
# Accuracy: 0.957
# Recall: 0.925
# Precision Score: 0.961
# F1-Score: 0.942
# Kappa Score: 0.908
# ==============================
# Clustering with 22 clusters
#  * Detected 22 rules / clusters
#  * Detected Sugeno model type
# Accuracy: 0.957
# Recall: 0.925
# Precision Score: 0.961
# F1-Score: 0.942
# Kappa Score: 0.908
# ==============================
# Clustering with 23 clusters
#  * Detected 23 rules / clusters
#  * Detected Sugeno model type
# Accuracy: 0.957
# Recall: 0.925
# Precision Score: 0.961
# F1-Score: 0.942
# Kappa Score: 0.908
# ==============================
# Clustering with 24 clusters
#  * Detected 24 rules / clusters
#  * Detected Sugeno model type
# Accuracy: 0.957
# Recall: 0.925
# Precision Score: 0.961
# F1-Score: 0.942
# Kappa Score: 0.908
# ==============================
# Clustering with 25 clusters
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 10
#       8 # Antecedent Estimation
#       9 ae = AntecedentEstimator(x_train, part_matrix)
# ---> 10 antecedent_params = ae.determineMF()
#      12 # Consequent Estimation
#      13 ce = ConsequentEstimator(x_train, y_train, part_matrix)
#
# File ~\anaconda3\envs\IntelSis\Lib\site-packages\pyfume\EstimateAntecendentSet.py:56, in AntecedentEstimator.determineMF(self, mf_shape, merge_threshold)
#      54 for j in range(0, self.partition_matrix.shape[1]):
#      55     mfin = self.partition_matrix[:,j]
# ---> 56     mf, xx = self._convexMF(xin=xin, mfin=mfin)
#      57     prm = self._fitMF(x=xx, mf=mf, mf_shape=mf_shape)
#      58     mf_list.append(prm)
#
# File ~\anaconda3\envs\IntelSis\Lib\site-packages\pyfume\EstimateAntecendentSet.py:205, in AntecedentEstimator._convexMF(self, xin, mfin, norm, nc)
#     203 for i in range(0,nc):
#     204     if np.any(mfin>acut[i]):
# --> 205         x[i]=np.min(xin[mfin>acut[i]])
#     206         x[i+nc]=np.max(xin[mfin>acut[i]])
#     207         mf[i]=acut[i]
#
# File ~\anaconda3\envs\IntelSis\Lib\site-packages\numpy\core\fromnumeric.py:2831, in _min_dispatcher(a, axis, out, keepdims, initial, where)
#    2817     """
#    2818     Return the maximum of an array or maximum along an axis.
#    2819
#    (...)
#    2825     ndarray.max : equivalent method
#    2826     """
#    2827     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2828                           keepdims=keepdims, initial=initial, where=where)
# -> 2831 def _min_dispatcher(a, axis=None, out=None, keepdims=None, initial=None,
#    2832                     where=None):
#    2833     return (a, out)
#    2836 @array_function_dispatch(_min_dispatcher)
#    2837 def min(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2838         where=np._NoValue):
#
# KeyboardInterrupt:
